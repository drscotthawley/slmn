# %%
#| hide
from slmn.nbtools import *
from slmn.misc import *

# %% [markdown]
# # slmn
#
# > Slammin' Language Model Nest -- a personal toolkit of LLM-workflow tools (notebook editing, PDF reading, CI checks, GPU checks, and more), usable three ways: import the functions directly, drive them from the `slmn` CLI, or expose them over an optional MCP server (`slmn-mcp`) for any MCP-speaking client.

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install slmn in Development mode

# %% [markdown]
# ```sh
# # make sure slmn package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to slmn
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/drscotthawley/slmn.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c drscotthawley slmn
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install slmn
# ```
#
#
# [repo]: https://github.com/drscotthawley/slmn
# [docs]: https://drscotthawley.github.io/slmn/
# [pypi]: https://pypi.org/project/slmn/
# [conda]: https://anaconda.org/drscotthawley/slmn

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/drscotthawley/slmn
# [docs]: https://drscotthawley.github.io/slmn/
# [pypi]: https://pypi.org/project/slmn/
# [conda]: https://anaconda.org/drscotthawley/slmn

# %% [markdown]
# ## How to use

# %% [markdown]
# Install (lite by default -- just the tools, no MCP server or its dependencies):
#
# ```sh
# pip install -e .
# ```
#
# Want the optional MCP server too? Install the `mcp` extra (pulls in `fastmcp` and friends):
#
# ```sh
# pip install -e ".[mcp]"
# ```
#
# Import tools directly:
#
# ```python
# from slmn.nbtools import grep_nb
# print(grep_nb('nbs/01_nbtools.ipynb', 'def read_nb'))
# ```
#
# Or from the shell:
#
# ```sh
# slmn grep_nb nbs/01_nbtools.ipynb 'def read_nb'
# slmn gpu_free
# ```
#
# Or (with the `mcp` extra installed) register the MCP server with any MCP-speaking client:
#
# ```sh
# claude mcp add slmn -- slmn-mcp
# ```

# %%
from slmn.misc import gpu_free
gpu_free()
# Out:
# 2
